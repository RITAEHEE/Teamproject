# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
# %config inlineBackend.figure_format ='retina'
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
import matplotlib.font_manager as fm
font_path = 'C:\Windows\Fonts\HMFMPYUN.TTF'
font_prop = fm.FontProperties(fname=font_path, size=20)
import seaborn as sns

# %%
g_2016=pd.read_csv('data/2016년 경기도 교통사고.csv', encoding='cp949')
g_2017=pd.read_csv('data/2017년 경기도 교통사고.csv', encoding='cp949')
g_2018=pd.read_csv('data/2018년 경기도 교통사고.csv', encoding='cp949')
g_2019=pd.read_csv('data/2019년 경기도 교통사고.csv', encoding='cp949')
g_2020=pd.read_csv('data/2020년 경기도 교통사고.csv', encoding='cp949')

# %%
gyounggi=pd.concat([g_2016,g_2017,g_2018,g_2019,g_2020])
gyounggi_si=gyounggi[gyounggi['시군구'].str.contains('경기도')]
gyounggi_si.index=range(gyounggi_si.shape[0])
gyounggi_suwon=gyounggi[gyounggi['시군구'].str.contains('수원시')]
gyounggi_suwon.index=range(gyounggi_suwon.shape[0])

# %% [markdown]
# # DL

# %%
data=pd.read_csv('data/suwonDL.csv', encoding='cp949',index_col=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23776 entries, 1 to 24359
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   요일        23776 non-null  object
#  1   사고내용      23776 non-null  int64
#  2   법규위반      23776 non-null  object
#  3   노면상태      23776 non-null  object
#  4   기상상태      23776 non-null  object
#  5   도로형태      23776 non-null  object
#  6   가해운전자_차종  23776 non-null  object
#  7   가해운전자_성별  23776 non-null  object
#  8   가해운전자_연령  23776 non-null  int64
#  9   행정동       23776 non-null  object
#  10  발생월       23776 non-null  int64
#  11  발생시간      23776 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 2.4+ MB

# %%
data
# Out:
#         요일  사고내용     법규위반     노면상태 기상상태         도로형태 가해운전자_차종 가해운전자_성별  \
# 1      금요일     1  안전운전불이행  포장 - 건조   맑음     단일로 - 기타       승용        남
# 2      금요일     1     신호위반  포장 - 건조   맑음  교차로 - 교차로부근       승용        남
# 3      금요일     0     신호위반  포장 - 건조   맑음   교차로 - 교차로안       화물        남
# 4      금요일     0  안전운전불이행  포장 - 건조   맑음  교차로 - 교차로부근       승용        남
# 5      금요일     0  안전운전불이행  포장 - 건조   맑음     단일로 - 기타       승용        남
# ...    ...   ...      ...      ...  ...          ...      ...      ...
# 24355  목요일     0       기타  포장 - 건조   맑음     단일로 - 기타       승용        남
# 24356  목요일     0  안전운전불이행  포장 - 건조   맑음     단일로 - 기타       승용        여
# 24357  목요일     0  안전거리미확보  포장 - 건조   맑음     단일로 - 기타      원동기        남
# 24358  목요일     0  안전운전불이행  포장 - 건조   맑음      기타 - 기타       승용        남
# 24359  목요일     0  안전운전불이행  포장 - 건조   맑음      기타 - 기타       승용        남
#
#        가해운전자_연령   행정동  발생월  발생시간
# 1            42  대황교동    1     4
# 2            57   인계동    1     4
# 3            26   우만동    1     5
# 4            23   인계동    1     6
# 5            31   우만동    1    11
# ...         ...   ...  ...   ...
# 24355        61   영화동   12    17
# 24356        19  호매실동   12    18
# 24357        21   입북동   12    18
# 24358        46   매탄동   12    19
# 24359        41   권선동   12    19
#
# [23776 rows x 12 columns]
